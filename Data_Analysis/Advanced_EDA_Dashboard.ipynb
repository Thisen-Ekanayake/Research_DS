# %% [markdown]
# # Advanced Exploratory Data Analysis & Diagnostics
#
# This supplementary notebook provides the deeper explanatory visualizations required to qualify the stationarity, demographic divisions, and time-lag constraints of the underemployment forecasting model.

# %% [markdown]
# ### 1. Demographic Breakdown: Gender Disparity over Time
# Highlighting the unequal impact of macro-economic constraints on the female workforce.

# %%
from IPython.display import Image
Image(filename='../Visualizations/Gender_Gap_Underemployment.png')

# %% [markdown]
# ### 2. Time Series Stationarity: Quarterly Boxplots
# Identifying non-stationary seasonal components and outliers that dictate the $SARIMA(p, d, q) \times (P, D, Q, s)$ framework structure.

# %%
from IPython.display import Image
Image(filename='../Visualizations/Quarterly_Seasonality_Boxplots.png')

# %% [markdown]
# ### 3. Economic Shock Probability: Regime Comparison
# KDE and Violin representations of how the statistical probability distribution of Underemployment fundamentally shifted following the 2020/2022 crises.

# %%
from IPython.display import Image
Image(filename='../Visualizations/Regime_Comparison_Violin_KDE.png')

# %% [markdown]
# ### 4. Cointegration Pre-Requisite: Time-Lagged Cross-Correlation (TLCC)
# Proving the existence of significant delay mechanisms (e.g. GDP dropping taking 1-2 years to fully impact working hours) to justify ARDL / VECM model selection.

# %%
from IPython.display import Image
Image(filename='../Visualizations/Lagged_Correlation_TLCC.png')
