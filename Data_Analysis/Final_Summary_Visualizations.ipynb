# %% [markdown]
# # Final Visualizations & Explanatory Dashboard
# This notebook aggregates all individual macro-economic markers and displays the final, publication-ready correlation matrices, SHAP explanations, and interactive timeline trends.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Image, display

# %% [markdown]
# ## 1. Global Correlation Matrix
# This matrix reveals how all features intercorrelate with the Unemployment Rate, enabling us to spot multi-collinearity.

# %%
display(Image(filename='../Visualizations/Global_Correlation_Matrix.png'))

# %% [markdown]
# ## 2. Combined Macro Trends over Time
# Comparing the top predictive variables directly against the Unemployment curve.

# %%
display(Image(filename='../Visualizations/Combined_Macro_Trends.png'))

# %% [markdown]
# ## 3. SHAP Model Explainability
# How strongly does each variable drive the Gradient Boosting prediction model?

# %%
print("SHAP Feature Impacts")
display(Image(filename='../shap_summary_plots.png'))
# Out:
# SHAP Feature Impacts

# %% [markdown]
# ## 4. Lagged Effects Importance
# Which economic markers perform best historically on a 2-year delay vs. current year?

# %%
display(Image(filename='../lagged_feature_importance.png'))
